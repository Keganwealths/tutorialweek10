# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\User\OneDrive\Desktop\practice files\dm_office_sales.csv')

# %%
df.head()
# Out:
#           division  level of education  training level  work experience
# 0         printers        some college               2                6  \
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   division            1000 non-null   object
#  1   level of education  1000 non-null   object
#  2   training level      1000 non-null   int64
#  3   work experience     1000 non-null   int64
#  4   salary              1000 non-null   int64
#  5   sales               1000 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 47.0+ KB

# %%
df.describe()
# Out:
#        training level  work experience         salary          sales
# count     1000.000000       1000.00000    1000.000000    1000.000000
# mean         1.262000          6.14200   90264.207000  339833.846000
# std          0.925317          2.94797   17398.617174  108555.773316
# min          0.000000          0.00000   41660.000000   53067.000000
# 25%          1.000000          4.00000   77584.000000  259257.500000
# 50%          1.000000          6.00000   89946.000000  338145.500000
# 75%          2.000000          8.00000  101834.250000  415210.250000
# max          3.000000         16.00000  159148.000000  761477.000000

# %%
df['division'].unique()
# Out:
# array(['printers', 'peripherals', 'office supplies', 'computer hardware',
#        'computer software'], dtype=object)

# %%
df['division'].value_counts()
# Out:
# division
# office supplies      252
# printers             250
# peripherals          243
# computer hardware    159
# computer software     96
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=df,x='division')
# Out:
# <Axes: xlabel='division', ylabel='count'>

# %%
df['level of education'].unique()
# Out:
# array(['some college', "associate's degree", 'high school',
#        "bachelor's degree", "master's degree"], dtype=object)

# %%
df['level of education'].value_counts()
# Out:
# level of education
# associate's degree    412
# some college          392
# high school           108
# bachelor's degree      85
# master's degree         3
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=df,x='level of education')
# Out:
# <Axes: xlabel='level of education', ylabel='count'>

# %%
df.shape
# Out:
# (1000, 6)

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=df, x='work experience')
# Out:
# <Axes: xlabel='work experience', ylabel='count'>

# %%
df['salary'].unique()
# Out:
# array([ 91684, 119679,  82045,  92949,  71280, 102401,  77548,  81966,
#         72844,  96731,  73508,  97841,  82719,  98070,  94604, 105864,
#         79103,  70834, 109279,  77126, 100478, 120849, 104805, 101064,
#         93307,  79557, 103623, 103102,  90624,  86992, 107167, 109170,
#         77464,  75556,  71739,  71754,  82212,  72889, 103149,  83792,
#         98668,  87697,  72061,  89007, 106439, 116489, 102285, 117441,
#         70683,  73325, 102889, 128685, 122039,  94155,  91294,  94787,
#        113059, 128460,  71579,  77722,  52324,  86125,  76575,  46061,
#         89958, 101181, 121184,  57580, 122903,  87644,  93659,  81859,
#         97604,  99223, 100790,  82876,  91973,  75155,  79042, 103816,
#        112198, 104068,  77010, 107821,  92038,  93920,  91768, 106885,
#         90970,  70523, 114278,  60365,  67849,  82344,  90567,  79247,
#         73426,  92602,  86105, 138975, 103966, 101638,  64852, 159148,
# ...

# %%
sal=df['salary'].value_counts()
len(sal)
# Out:
# 993

# %%
plt.figure(figsize=(12,8))
#sns.rugplot(data=df,x='salary',height=0.8)
sns.histplot(data=df,x='salary')
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=df, x='division', y='salary', estimator=np.mean)
# Out:
# <Axes: xlabel='division', ylabel='salary'>

# %%
sns.scatterplot(data=df,x='sales',y='salary',size='training level')
plt.legend(bbox_to_anchor=(1.05,1))

# %%
sns.relplot(data=df,x='sales',y='salary',hue='division',col='division',row='training level')
